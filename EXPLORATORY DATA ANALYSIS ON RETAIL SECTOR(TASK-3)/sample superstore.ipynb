# %% [markdown]
# # Exploring Buisness Analytics
#
#
# OBJECTIVE:
#
# ● Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#
# ● As a business manager, try to find out the weak areas where you can work to make more profit.
#
# ● What all business problems you can derive by exploring the data?
#
# Author: Lucky Agarwal
# Copyright LuckyAgarwal ,2021

# %% [raw]
# Importing Essential Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from warnings import filterwarnings
filterwarnings('ignore')

# %% [raw]
# Reading the data file

# %%
df=pd.read_csv('C:\\Users\\LUCKY\\Downloads\\sparks foundation\\EXPLORATORY DATA ANALYSIS ON RETAIL SECTOR(TASK-3)\\SampleSuperstore.csv')

df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [raw]
# Checking the shape of dataset

# %%
df.shape
# Out:
# (9994, 13)

# %% [raw]
# #there are 9994 records
# # there are 13 columns

# %% [raw]
# finding the datatype of each column

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [raw]
# # all columns have been assigned proper datatype

# %% [raw]
# checking the 5 point summary of the numerical columns

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [raw]
# # the count shows that there is no missing values present
# # there is diffrence seen between mean and median value ,we can draw an inference that these coumns have outliers and since mean value is higher than median we can say that the distribution of profit and sales is RIGHT SKEWED
# #Quantity and Discount are near normal

# %%
df.skew()
# Out:
# Postal Code    -0.128526
# Sales          12.972752
# Quantity        1.278545
# Discount        1.684295
# Profit          7.561432
# dtype: float64

# %% [raw]
# profit and sales are right skewed

# %%
#Confirming the presence of null values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [raw]
# # there are no null values present in the dataset

# %%
# checking for duplicate records
df[df.duplicated()]
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# 7735  Standard Class    Corporate  United States        Seattle    Washington
# ...

# %%
#dropping duplicate records:
df=df.drop_duplicates()
print('the no of duplicated record is:',df.duplicated().sum())
# Out:
# the no of duplicated record is: 0

# %%
df_num=df.select_dtypes(include=np.number)
df_cat=df.select_dtypes(object)
df_cat['Postal Code'] = df_num['Postal Code']
df_num = df_num.drop(['Postal Code'],1)
print('the numerical columns are :', df_num.columns)
print('\n')
print('the categorical columns are :', df_cat.columns)
# Out:
# the numerical columns are : Index(['Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')
#
#
# the categorical columns are : Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category', 'Postal Code'],
#       dtype='object')

# %% [markdown]
# # Univariate analysis

# %%
# analysis for categorical columns;
for i in df_cat.columns:
    print(pd.DataFrame({'Count':df[i].value_counts(),'percentage':df[i].value_counts(normalize=True)*100}))
    print('\n')
# Out:
#                 Count  percentage
# Standard Class   5955   59.687281
# Second Class     1943   19.474792
# First Class      1537   15.405432
# Same Day          542    5.432495
#
#
#              Count  percentage
# Consumer      5183   51.949484
# Corporate     3015   30.219505
# Home Office   1779   17.831011
#
#
#                Count  percentage
# United States   9977       100.0
#
#
#                Count  percentage
# New York City    914    9.161070
# Los Angeles      746    7.477198
# Philadelphia     536    5.372356
# San Francisco    506    5.071665
# Seattle          424    4.249774
# ...              ...         ...
# Palatine           1    0.010023
# Hagerstown         1    0.010023
# Rock Hill          1    0.010023
# Conroe             1    0.010023
# Antioch            1    0.010023
#
# [531 rows x 2 columns]
#
#
#                       Count  percentage
# California             1996   20.006014
# New York               1127   11.295981
# ...

# %%
# the column COUNTRY has only united states as a country , so the column add no relevance to dataset,therefore we drop it
df=df.drop('Country',1)

# %%
# analysis for numerical columns:
plt.rcParams['figure.figsize']=(8,6)
for i in df_num.columns:
    sns.boxplot(df[i])
    plt.show()

# %%
plt.rcParams['figure.figsize']=(6,6)
for i in df_num.columns:
    sns.distplot(df[i],kde=True)
    plt.show()

# %% [raw]
# # there are outliers present and hence skewness is seen in every distribution.

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# LOSS MAKING STATES

# %%
plt.figure(figsize=(30,12))
sns.barplot(df[df['Profit']<=0]['State'],df[df['Profit']<=0]['Profit'])
plt.xticks(rotation=55,fontsize=20)
plt.show()

# %% [raw]
# the above states are the ones where profit is on the negative side
# Reason for loss need to be taken into consideration,to improve business setup

# %%
# region wise plot against loss made 
plt.figure(figsize=(8,6))
sns.barplot(df['Region'], df[df['Profit']<=0]['Profit'])
plt.show()

# %% [raw]
# south region is the  highest loss making region
# whereas west has least.

# %%
plt.figure(figsize=(8,6))
sns.barplot(df['Ship Mode'], df[df['Profit']<=0]['Profit'])
plt.show()

# %% [raw]
# The shipmode which is on the same day might yeild certain loss as per the data

# %%
plt.figure(figsize=(8,6))
sns.barplot(df['Segment'], df[df['Profit']<=0]['Profit'])
plt.show()

# %% [raw]
# the plot shows that almost same loss is seen across all three segments

# %%
ax=df.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['green','red'],figsize=(8,5))
plt.ylabel('Profit/Loss vs sales')

plt.show()

# %% [raw]
# AS we can see Technology being higher sales drawing our higher profits.
# The weaker Category can be Furniture as the sales are significant but the profit is not reliable.

# %%
df.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['green','red'],figsize=(8,5))
plt.ylabel('Profit/Loss vs sales')
plt.show()

# %% [raw]
# Home Office segment was not really contributing much to profits, but it has certain capacity to draw more profits if the sales numbers goes up

# %%
df.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['green','red'],figsize=(8,5))
plt.ylabel('Profit/Loss vs sales')
plt.show()

# %% [raw]
# The sales numbers of South vs profit depicts the potential ,focusing more on such region can help organization to derive more profits.

# %%
df.groupby('Sub-Category')[['Profit','Sales']].sum().plot.bar(color=['green','red'],figsize=(13,7))
plt.ylabel('Profit/Loss vs sales')
plt.show()

# %% [raw]
# Tables and Bookcases category incurring losses even after good amount of sales numbers.
# Line of focus can shift on to these two categories to register profits or can be stopped from being sold .
# There is minimal profit registered from Fasteners though the deamnd is also less for it.
# Selling large number of Machines and chairs still not helping out to make profits,Machines can also be under Radar.
